# %% [markdown]
# <a href="https://colab.research.google.com/github/saadz-khan/Text2Image/blob/master/animations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Setup and Library Installation

from IPython.utils import io
with io.capture_output() as captured:
  # !pip3 install torch==1.4.0+cu100 torchvision==0.5.0+cu100 -f https://download.pytorch.org/whl/torch_stable.html
  # !pip3 install opencv-python==4.2.0.32
  # !pip3 install vispy==0.6.4
  # !pip3 install moviepy==1.0.2
  # !pip3 install transforms3d==0.3.1
  # !pip3 install networkx==2.3
  # !sudo apt install sed
  # !pip install gradio==2.3.7
  import os

  if os.path.exists('/content/drive/MyDrive/pixray/3d-photo-inpainting'):
    pass
  else:
    # !mkdir /content/drive/MyDrive/pixray
    # %cd /content/drive/MyDrive/pixray
    # !git clone https://github.com/vt-vl-lab/3d-photo-inpainting.git
  # %cd /content/drive/MyDrive/pixray/3d-photo-inpainting
  # !sh download.sh

  # Switch off off-screen rendering
  
  # !sed -i 's/offscreen_rendering: True/offscreen_rendering: False/g' argument.yml

  import os
  os.kill(os.getpid(), 9)

# %%
#@title User Interface 
#@markdown Run the play button and select the link generated down below.

import gradio as gr
from PIL import Image
import torch
import numpy as np
import os
import time
from moviepy.editor import *
import yaml


def change_yaml(total_frames, fps, longest_side):
  #largest_size = 512
  #total_frames = 240
  #fps = 40
  #longest_side = 2000
  path = '/content/drive/MyDrive/pixray/3d-photo-inpainting/argument.yml'
  # !rm -rf {path}

  yaml_dict = {'MiDaS_model_ckpt': 'MiDaS/model.pt',
  'anti_flickering': True,
  'background_thickness': 70,
  'background_thickness_2': 70,
  'context_thickness': 140,
  'context_thickness_2': 70,
  'crop_border': [0.03, 0.03, 0.05, 0.03],
  'depth_edge_dilate': 10,
  'depth_edge_dilate_2': 5,
  'depth_edge_model_ckpt': 'checkpoints/edge-model.pth',
  'depth_feat_model_ckpt': 'checkpoints/depth-model.pth',
  'depth_folder': 'depth',
  'depth_format': '.npy',
  'depth_threshold': 0.04,
  'discount_factor': 1.0,
  'ext_edge_threshold': 0.002,
  'extrapolate_border': True,
  'extrapolation_thickness': 60,
  'filter_size': [7, 7, 5, 5, 5],
  'fps': int(fps),
  'gpu_ids': 0,
  'img_format': '.png',
  'inference_video': True,
  'largest_size': 512,
  'load_ply': False,
  'log_depth': True,
  'longer_side_len': int(longest_side),
  'mesh_folder': 'mesh',
  'num_frames': int(total_frames),
  'offscreen_rendering': False,
  'redundant_number': 12,
  'repeat_inpaint_edge': True,
  'require_midas': True,
  'rgb_feat_model_ckpt': 'checkpoints/color-model.pth',
  'save_ply': False,
  'sigma_r': 0.5,
  'sigma_s': 4.0,
  'sparse_iter': 5,
  'specific': '',
  'src_folder': 'image',
  'traj_types': ['double-straight-line'],
  'use_boostmonodepth': True,
  'video_folder': 'video',
  'video_postfix': ['dolly-zoom-in'],
  'x_shift_range': [0.0],
  'y_shift_range': [0.0],
  'z_shift_range': [-0.05]}

  with open(path, 'w') as file:
    yaml.dump(yaml_dict, file)


def generate(image, folder, dest_folder, size, fps, total_frames):
  # %cd /content/drive/MyDrive/pixray/3d-photo-inpainting
  base_path = '/content/drive/MyDrive/pixray/3d-photo-inpainting'
  torch.cuda.empty_cache()
  # !rm -rf {base_path}/image
  # !rm -rf {base_path}/video
  # !mkdir {base_path}/image
  # !mkdir {base_path}/video
  # !mkdir {base_path}/results
  # !mkdir {base_path}/results/{dest_folder}

  change_yaml(int(total_frames), int(fps), int(size))

  i = 0
  ext = ('.png', 'jpg')
  if (folder != '/content/drive/MyDrive/'):
    for f in os.listdir(folder):
      if f.endswith(ext):
        # !rm -rf {base_path}/image
        # !mkdir {base_path}/image
        image = Image.open(folder+'/'+f)
        image.save(f'{base_path}/image/image{i}.png')
      else:
        continue

      # !python main.py --config argument.yml
      while not os.path.exists(f'{base_path}/video/image{i}_dolly-zoom-in.mp4'):
        time.sleep(10)

      # !python reverse_video.py /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image{i}_dolly-zoom-in.mp4

      # loading video dsa gfg intro video
      clip1 = VideoFileClip(f"/content/drive/MyDrive/pixray/3d-photo-inpainting/video/image{i}_dolly-zoom-in.mp4")
      clip2 = VideoFileClip(f"/content/drive/MyDrive/pixray/3d-photo-inpainting/video/image{i}_dolly-zoom-in-inverted.mp4") 

      # concatenating both the clips
      final1 = concatenate_videoclips([clip1,clip2,clip1,clip2,clip1,clip2])
      final2 = concatenate_videoclips([clip1,clip2])
    
      #writing the video into a file / saving the combined video
      final1.write_videofile(f"{base_path}/video/image{i}.mp4")
      #final2.write_gif(f"{base_path}/video/image{i}.gif")
      i = i + 1

      # !mv  -v {base_path}/video/* {base_path}/results/{dest_folder}      
    return f'{base_path}/results/{dest_folder}/image{i-1}.mp4'
      

  else:  
    image = Image.fromarray(image)
    image.save(f'{base_path}/image/image{i}.png')
    
    # !python main.py --config argument.yml
    while not os.path.exists(f'{base_path}/video/image{i}_dolly-zoom-in.mp4'):
      time.sleep(10)
    # !python reverse_video.py /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image{i}_dolly-zoom-in.mp4

    # loading video dsa gfg intro video
    clip1 = VideoFileClip(f"/content/drive/MyDrive/pixray/3d-photo-inpainting/video/image{i}_dolly-zoom-in.mp4")
    clip2 = VideoFileClip(f"/content/drive/MyDrive/pixray/3d-photo-inpainting/video/image{i}_dolly-zoom-in-inverted.mp4") 

    # concatenating both the clips
    final = concatenate_videoclips([clip1,clip2,clip1,clip2,clip1,clip2])
    
    #writing the video into a file / saving the combined video
    final.write_videofile(f"{base_path}/video/image{i}.mp4")
    #final.write_gif(f"{base_path}/video/image{i}.gif")
    i = i + 1
    # !mv  -v {base_path}/video/* {base_path}/results/{dest_folder}
    return f'/{base_path}/{dest_folder}/image{i-1}.mp4'

# Create the UI
image = gr.inputs.Image(label = 'Image Upload', optional=True)
folder = gr.inputs.Textbox(label = 'Image folder to animate', default = '/content/drive/MyDrive/')
dest_folder = gr.inputs.Textbox(label = 'Destination Folder Name')
size = gr.inputs.Number(label="Longest side size", default=2000)
fps = gr.inputs.Number(label="Frames per second (fps)", default=40)
total_frames = gr.inputs.Number(label="Total Number of frames", default=240)



# Launch the demo
iface = gr.Interface(generate, inputs=[image, folder, dest_folder, size, fps, total_frames], outputs=['video'], enable_queue=True, live=False, title='Animations')
iface.launch(debug=True)
# Out:
# IMPORTANT: You are using gradio version 2.3.7, however version 2.5.1 is available, please upgrade.
# --------
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces (https://huggingface.co/spaces)
# [2022-05-05 09:29:30,255] ERROR in app: Exception on /api/queue/status/ [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.7/dist-packages/flask_cors/extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.7/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/local/lib/python3.7/dist-packages/gradio/networking.py", line 90, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/gradio/networking.py", line 397, in queue_status
#     status, data = queue.get_status(hash)
#   File "/usr/local/lib/python3.7/dist-packages/gradio/queue.py", line 104, in get_status
#     raise ValueError("Hash not found.")
# ValueError: Hash not found.
# Running on public URL: https://29181.gradio.app
# Interface loading below...
#         <iframe
#             width="900"
#             height="500"
#             src="https://29181.gradio.app"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# /content/drive/MyDrive/pixray/3d-photo-inpainting
# mkdir: cannot create directory ‘/content/drive/MyDrive/pixray/3d-photo-inpainting/results’: File exists
# mkdir: cannot create directory ‘/content/drive/MyDrive/pixray/3d-photo-inpainting/results/result_testing’: File exists
# running on device 0
#   0% 0/1 [00:00<?, ?it/s]Current Source ==>  image0
# Running depth extraction at 1651742997.1767063
# BoostingMonocularDepth/inputs/*.png
# /usr/local/lib/python3.7/dist-packages/paramiko/transport.py:236: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# device: cuda
# Namespace(Final=True, R0=False, R20=False, colorize_results=False, data_dir='inputs/', depthNet=0, max_res=inf, net_receptive_field_size=None, output_dir='outputs', output_resolution=1, pix2pixsize=1024, savepatchs=0, savewholeest=0)
# ----------------- Options ---------------
#                     Final: True                          	[default: False]
#                        R0: False
#                       R20: False
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./pix2pix/checkpoints
#          colorize_results: False
#                 crop_size: 672
#                  data_dir: inputs/                       	[default: None]
#                  dataroot: None
#              dataset_mode: depthmerge
#                  depthNet: 0                             	[default: None]
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#             generatevideo: None
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 2
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 672
#          max_dataset_size: 10000
#                   max_res: inf
#                     model: pix2pix4depth
#                n_layers_D: 3
#                      name: void
#                       ndf: 64
#                      netD: basic
#                      netG: unet_1024
#  net_receptive_field_size: None
#                       ngf: 64
#                no_dropout: False
#                   no_flip: False
#                      norm: none
#                  num_test: 50
#               num_threads: 4
#                output_dir: outputs                       	[default: None]
#                 output_nc: 1
#         output_resolution: None
#                     phase: test
#               pix2pixsize: None
#                preprocess: resize_and_crop
#                 savecrops: None
#              savewholeest: None
#            serial_batches: False
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
# initialize network with normal
# loading the model from ./pix2pix/checkpoints/mergemodel/latest_net_G.pth
# Loading weights:  midas/model.pt
# Using cache found in /root/.cache/torch/hub/facebookresearch_WSL-Images_main
# start processing
# processing image 0 : image0
# 	 wholeImage being processed in : 2112
#  	 	 DEBUG| GPU THRESHOLD REACHED 2112 ---> 1568
# Adjust factor is: 1.0
# Selecting patchs ...
# Target resolution:  (4224, 3122, 3)
# Dynamicly change merged-in resolution; scale: 0.17424242424242425
# 	 Resulted depthmap res will be : (736, 544)
# patchs to process: 66
# 	 processing patch 0 | [  0 201 535 535]
# 	 processing patch 1 | [ 92 192 452 452]
# 	 processing patch 2 | [ 92 243 452 452]
# 	 processing patch 3 | [  0 251 435 435]
# 	 processing patch 4 | [  0 301 435 435]
# 	 processing patch 5 | [ 50 301 435 435]
# 	 processing patch 6 | [100 301 435 435]
# 	 processing patch 7 | [ 36  86 362 362]
# 	 processing patch 8 | [192 243 351 351]
# 	 processing patch 9 | [192 293 351 351]
# 	 processing patch 10 | [192 343 351 351]
# 	 processing patch 11 | [  0 351 335 335]
# 	 processing patch 12 | [  0 401 335 335]
# 	 processing patch 13 | [ 50  50 335 335]
# 	 processing patch 14 | [ 50 401 335 335]
# 	 processing patch 15 | [100 401 335 335]
# 	 processing patch 16 | [151 401 335 335]
# 	 processing patch 17 | [201 401 335 335]
# 	 processing patch 18 | [ 64  14 307 307]
# 	 processing patch 19 | [ 20  70 296 296]
# 	 processing patch 20 | [120  70 296 296]
# 	 processing patch 21 | [123  22 290 290]
# 	 processing patch 22 | [ 31  31 273 273]
# 	 processing patch 23 | [137 137 262 262]
# 	 processing patch 24 | [187  86 262 262]
# 	 processing patch 25 | [293 243 251 251]
# 	 processing patch 26 | [293 293 251 251]
# 	 processing patch 27 | [293 343 251 251]
# 	 processing patch 28 | [293 393 251 251]
# 	 processing patch 29 | [293 443 251 251]
# 	 processing patch 30 | [  0 301 234 234]
# 	 processing patch 31 | [  0 351 234 234]
# 	 processing patch 32 | [  0 401 234 234]
# 	 processing patch 33 | [  0 452 234 234]
# 	 processing patch 34 | [ 50 502 234 234]
# 	 processing patch 35 | [100   0 234 234]
# 	 processing patch 36 | [100 502 234 234]
# 	 processing patch 37 | [151   0 234 234]
# 	 processing patch 38 | [251 502 234 234]
# 	 processing patch 39 | [301 502 234 234]
# 	 processing patch 40 | [206 156 223 223]
# 	 processing patch 41 | [ 59   8 217 217]
# 	 processing patch 42 | [ 11 262 212 212]
# 	 processing patch 43 | [217  67 201 201]
# 	 processing patch 44 | [ 20 521 195 195]
# 	 processing patch 45 | [ 31 181 173 173]
# 	 processing patch 46 | [237 237 162 162]
# 	 processing patch 47 | [ 39 240 156 156]
# 	 processing patch 48 | [340  39 156 156]
# 	 processing patch 49 | [243 293 151 151]
# 	 processing patch 50 | [393  42 151 151]
# 	 processing patch 51 | [393 293 151 151]
# 	 processing patch 52 | [393 343 151 151]
# 	 processing patch 53 | [393 393 151 151]
# 	 processing patch 54 | [393 443 151 151]
# 	 processing patch 55 | [393 493 151 151]
# 	 processing patch 56 | [393 544 151 151]
# 	 processing patch 57 | [  0 251 134 134]
# 	 processing patch 58 | [  0 301 134 134]
# 	 processing patch 59 | [  0 351 134 134]
# 	 processing patch 60 | [  0 401 134 134]
# 	 processing patch 61 | [  0 452 134 134]
# 	 processing patch 62 | [  0 502 134 134]
# 	 processing patch 63 | [251  50 134 134]
# 	 processing patch 64 | [351   0 134 134]
# 	 processing patch 65 | [401   0 134 134]
# finished
# Start Running 3D_Photo ...
# Loading edge model at 1651743070.073334
# Loading depth model at 1651743072.6664548
# Loading rgb model at 1651743073.5093591
# Writing depth ply (and basically doing everything) at 1651743074.290448
# Making video at 1651743490.5638967
# fov: 53.13010235415598
# Moviepy - Building video video/image0_dolly-zoom-in.mp4.
# Moviepy - Writing video video/image0_dolly-zoom-in.mp4
#
#   0% 0/1 [09:17<?, ?it/s]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   2% 5/241 [00:00<00:04, 47.94it/s, now=None]
# t:   4% 10/241 [00:00<00:04, 48.83it/s, now=None]
# t:   7% 16/241 [00:00<00:04, 49.84it/s, now=None]
# t:   9% 22/241 [00:00<00:04, 50.99it/s, now=None]
# t:  12% 28/241 [00:00<00:04, 50.95it/s, now=None]
# t:  14% 34/241 [00:00<00:04, 50.88it/s, now=None]
# t:  17% 40/241 [00:00<00:03, 51.38it/s, now=None]
# t:  19% 46/241 [00:00<00:03, 51.43it/s, now=None]
# t:  22% 52/241 [00:01<00:06, 29.71it/s, now=None]
# t:  24% 57/241 [00:01<00:06, 29.84it/s, now=None]
# t:  25% 61/241 [00:01<00:06, 29.04it/s, now=None]
# t:  27% 65/241 [00:01<00:06, 28.58it/s, now=None]
# t:  29% 69/241 [00:01<00:06, 28.64it/s, now=None]
# t:  30% 73/241 [00:02<00:05, 28.59it/s, now=None]
# t:  32% 77/241 [00:02<00:05, 27.73it/s, now=None]
# t:  33% 80/241 [00:02<00:05, 27.15it/s, now=None]
# t:  34% 83/241 [00:02<00:05, 26.82it/s, now=None]
# t:  36% 86/241 [00:02<00:05, 27.38it/s, now=None]
# t:  37% 90/241 [00:02<00:05, 29.22it/s, now=None]
# t:  39% 94/241 [00:02<00:04, 30.37it/s, now=None]
# t:  41% 98/241 [00:02<00:05, 25.01it/s, now=None]
# t:  42% 102/241 [00:03<00:05, 27.17it/s, now=None]
# t:  44% 105/241 [00:03<00:05, 24.49it/s, now=None]
# t:  45% 108/241 [00:03<00:07, 16.90it/s, now=None]
# t:  46% 111/241 [00:03<00:07, 18.47it/s, now=None]
# t:  47% 114/241 [00:03<00:06, 20.00it/s, now=None]
# t:  49% 117/241 [00:03<00:05, 21.65it/s, now=None]
# t:  50% 120/241 [00:04<00:05, 20.27it/s, now=None]Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 285, in ffmpeg_parse_infos
#     line = [l for l in lines if keyword in l][index]
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "reverse_video.py", line 75, in <module>
#     frames_folder_path, video_fps = extract_frames(video_file)
#   File "reverse_video.py", line 28, in extract_frames
#     video_clip = VideoFileClip(video_file)
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/VideoFileClip.py", line 91, in __init__
#     fps_source=fps_source)
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 36, in __init__
#     fps_source)
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 291, in ffmpeg_parse_infos
#     filename, infos))
# OSError: MoviePy error: failed to read the duration of file /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0_dolly-zoom-in.mp4.
# Here are the file infos returned by ffmpeg:
#
# ffmpeg version 4.2.2-static https://johnvansickle.com/ffmpeg/  Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 8 (Debian 8.3.0-6)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-debug --disable-ffplay --disable-indev=sndio --disable-outdev=sndio --cc=gcc --enable-fontconfig --enable-frei0r --enable-gnutls --enable-gmp --enable-libgme --enable-gray --enable-libaom --enable-libfribidi --enable-libass --enable-libvmaf --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librubberband --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libvorbis --enable-libopus --enable-libtheora --enable-libvidstab --enable-libvo-amrwbenc --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libdav1d --enable-libxvid --enable-libzvbi --enable-libzimg
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x643f580] moov atom not found
# /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0_dolly-zoom-in.mp4: Invalid data found when processing input
#
#
# t:  51% 123/241 [00:04<00:06, 18.16it/s, now=None]Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 285, in ffmpeg_parse_infos
#     line = [l for l in lines if keyword in l][index]
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "reverse_video.py", line 75, in <module>
#     frames_folder_path, video_fps = extract_frames(video_file)
#   File "reverse_video.py", line 28, in extract_frames
#     video_clip = VideoFileClip(video_file)
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/VideoFileClip.py", line 91, in __init__
#     fps_source=fps_source)
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 36, in __init__
#     fps_source)
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 291, in ffmpeg_parse_infos
#     filename, infos))
# OSError: MoviePy error: failed to read the duration of file /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0_dolly-zoom-in.mp4.
# Here are the file infos returned by ffmpeg:
#
# ffmpeg version 4.2.2-static https://johnvansickle.com/ffmpeg/  Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 8 (Debian 8.3.0-6)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-debug --disable-ffplay --disable-indev=sndio --disable-outdev=sndio --cc=gcc --enable-fontconfig --enable-frei0r --enable-gnutls --enable-gmp --enable-libgme --enable-gray --enable-libaom --enable-libfribidi --enable-libass --enable-libvmaf --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librubberband --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libvorbis --enable-libopus --enable-libtheora --enable-libvidstab --enable-libvo-amrwbenc --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libdav1d --enable-libxvid --enable-libzvbi --enable-libzimg
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x5d76580] moov atom not found
# /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0_dolly-zoom-in.mp4: Invalid data found when processing input
#
#
# t:  52% 126/241 [00:04<00:06, 18.51it/s, now=None]
# [2022-05-05 09:39:19,174] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 285, in ffmpeg_parse_infos
#     line = [l for l in lines if keyword in l][index]
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.7/dist-packages/flask_cors/extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.7/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/local/lib/python3.7/dist-packages/gradio/networking.py", line 90, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/gradio/networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "/usr/local/lib/python3.7/dist-packages/gradio/interface.py", line 350, in process
#     processed_input, return_duration=True)
#   File "/usr/local/lib/python3.7/dist-packages/gradio/interface.py", line 322, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-3-6d80249cbcb1>", line 105, in generate
#     clip1 = VideoFileClip(f"/content/drive/MyDrive/pixray/3d-photo-inpainting/video/image{i}_dolly-zoom-in.mp4")
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/VideoFileClip.py", line 91, in __init__
#     fps_source=fps_source)
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 36, in __init__
#     fps_source)
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 291, in ffmpeg_parse_infos
#     filename, infos))
# OSError: MoviePy error: failed to read the duration of file /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0_dolly-zoom-in.mp4.
# Here are the file infos returned by ffmpeg:
#
# ffmpeg version 4.2.2-static https://johnvansickle.com/ffmpeg/  Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 8 (Debian 8.3.0-6)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-debug --disable-ffplay --disable-indev=sndio --disable-outdev=sndio --cc=gcc --enable-fontconfig --enable-frei0r --enable-gnutls --enable-gmp --enable-libgme --enable-gray --enable-libaom --enable-libfribidi --enable-libass --enable-libvmaf --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librubberband --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libvorbis --enable-libopus --enable-libtheora --enable-libvidstab --enable-libvo-amrwbenc --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libdav1d --enable-libxvid --enable-libzvbi --enable-libzimg
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x6bd5580] moov atom not found
# /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0_dolly-zoom-in.mp4: Invalid data found when processing input
# t:  54% 129/241 [00:04<00:05, 20.74it/s, now=None]
# [2022-05-05 09:39:19,229] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 285, in ffmpeg_parse_infos
#     line = [l for l in lines if keyword in l][index]
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.7/dist-packages/flask_cors/extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.7/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/local/lib/python3.7/dist-packages/gradio/networking.py", line 90, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/gradio/networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "/usr/local/lib/python3.7/dist-packages/gradio/interface.py", line 350, in process
#     processed_input, return_duration=True)
#   File "/usr/local/lib/python3.7/dist-packages/gradio/interface.py", line 322, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-1-26a2febfb0ac>", line 105, in generate
#     clip1 = VideoFileClip(f"/content/drive/MyDrive/pixray/3d-photo-inpainting/video/image{i}_dolly-zoom-in.mp4")
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/VideoFileClip.py", line 91, in __init__
#     fps_source=fps_source)
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 36, in __init__
#     fps_source)
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 291, in ffmpeg_parse_infos
#     filename, infos))
# OSError: MoviePy error: failed to read the duration of file /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0_dolly-zoom-in.mp4.
# Here are the file infos returned by ffmpeg:
#
# ffmpeg version 4.2.2-static https://johnvansickle.com/ffmpeg/  Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 8 (Debian 8.3.0-6)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-debug --disable-ffplay --disable-indev=sndio --disable-outdev=sndio --cc=gcc --enable-fontconfig --enable-frei0r --enable-gnutls --enable-gmp --enable-libgme --enable-gray --enable-libaom --enable-libfribidi --enable-libass --enable-libvmaf --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librubberband --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libvorbis --enable-libopus --enable-libtheora --enable-libvidstab --enable-libvo-amrwbenc --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libdav1d --enable-libxvid --enable-libzvbi --enable-libzimg
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x6a08580] moov atom not found
# /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0_dolly-zoom-in.mp4: Invalid data found when processing input
# t:  55% 132/241 [00:04<00:04, 22.13it/s, now=None]
# t:  56% 136/241 [00:04<00:04, 24.31it/s, now=None]
# t:  58% 139/241 [00:04<00:04, 25.15it/s, now=None]
# t:  59% 143/241 [00:05<00:03, 27.11it/s, now=None]
# t:  61% 146/241 [00:05<00:03, 27.44it/s, now=None]Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 285, in ffmpeg_parse_infos
#     line = [l for l in lines if keyword in l][index]
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "reverse_video.py", line 75, in <module>
#     frames_folder_path, video_fps = extract_frames(video_file)
#   File "reverse_video.py", line 28, in extract_frames
#     video_clip = VideoFileClip(video_file)
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/VideoFileClip.py", line 91, in __init__
#     fps_source=fps_source)
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 36, in __init__
#     fps_source)
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 291, in ffmpeg_parse_infos
#     filename, infos))
# OSError: MoviePy error: failed to read the duration of file /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0_dolly-zoom-in.mp4.
# Here are the file infos returned by ffmpeg:
#
# ffmpeg version 4.2.2-static https://johnvansickle.com/ffmpeg/  Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 8 (Debian 8.3.0-6)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-debug --disable-ffplay --disable-indev=sndio --disable-outdev=sndio --cc=gcc --enable-fontconfig --enable-frei0r --enable-gnutls --enable-gmp --enable-libgme --enable-gray --enable-libaom --enable-libfribidi --enable-libass --enable-libvmaf --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librubberband --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libvorbis --enable-libopus --enable-libtheora --enable-libvidstab --enable-libvo-amrwbenc --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libdav1d --enable-libxvid --enable-libzvbi --enable-libzimg
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x56d2580] moov atom not found
# /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0_dolly-zoom-in.mp4: Invalid data found when processing input
#
#
# t:  62% 149/241 [00:05<00:03, 27.42it/s, now=None]
# [2022-05-05 09:39:20,045] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 285, in ffmpeg_parse_infos
#     line = [l for l in lines if keyword in l][index]
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.7/dist-packages/flask_cors/extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.7/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/local/lib/python3.7/dist-packages/gradio/networking.py", line 90, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/gradio/networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "/usr/local/lib/python3.7/dist-packages/gradio/interface.py", line 350, in process
#     processed_input, return_duration=True)
#   File "/usr/local/lib/python3.7/dist-packages/gradio/interface.py", line 322, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-4-83cd6f8f52a1>", line 106, in generate
#     clip1 = VideoFileClip(f"/content/drive/MyDrive/pixray/3d-photo-inpainting/video/image{i}_dolly-zoom-in.mp4")
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/VideoFileClip.py", line 91, in __init__
#     fps_source=fps_source)
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 36, in __init__
#     fps_source)
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 291, in ffmpeg_parse_infos
#     filename, infos))
# OSError: MoviePy error: failed to read the duration of file /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0_dolly-zoom-in.mp4.
# Here are the file infos returned by ffmpeg:
#
# ffmpeg version 4.2.2-static https://johnvansickle.com/ffmpeg/  Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 8 (Debian 8.3.0-6)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-debug --disable-ffplay --disable-indev=sndio --disable-outdev=sndio --cc=gcc --enable-fontconfig --enable-frei0r --enable-gnutls --enable-gmp --enable-libgme --enable-gray --enable-libaom --enable-libfribidi --enable-libass --enable-libvmaf --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librubberband --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libvorbis --enable-libopus --enable-libtheora --enable-libvidstab --enable-libvo-amrwbenc --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libdav1d --enable-libxvid --enable-libzvbi --enable-libzimg
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x60c2580] moov atom not found
# /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0_dolly-zoom-in.mp4: Invalid data found when processing input
# t:  63% 152/241 [00:05<00:03, 25.52it/s, now=None]
# t:  64% 155/241 [00:05<00:03, 25.48it/s, now=None]
# t:  66% 158/241 [00:05<00:03, 26.18it/s, now=None]
# t:  67% 161/241 [00:05<00:03, 26.46it/s, now=None]
# t:  68% 164/241 [00:05<00:02, 26.73it/s, now=None]
# t:  69% 167/241 [00:05<00:02, 26.79it/s, now=None]
# t:  71% 171/241 [00:06<00:02, 27.32it/s, now=None]
# t:  72% 174/241 [00:06<00:02, 26.94it/s, now=None]
# t:  73% 177/241 [00:06<00:02, 27.20it/s, now=None]
# t:  75% 180/241 [00:06<00:02, 27.60it/s, now=None]
# t:  76% 183/241 [00:06<00:02, 27.35it/s, now=None]
# t:  77% 186/241 [00:06<00:02, 26.52it/s, now=None]
# t:  78% 189/241 [00:06<00:01, 27.32it/s, now=None]
# t:  80% 193/241 [00:06<00:01, 28.96it/s, now=None]
# t:  81% 196/241 [00:07<00:01, 28.80it/s, now=None]
# t:  83% 199/241 [00:07<00:01, 28.49it/s, now=None]
# t:  84% 202/241 [00:07<00:01, 26.18it/s, now=None]
# t:  85% 205/241 [00:07<00:01, 26.48it/s, now=None]
# t:  86% 208/241 [00:07<00:01, 26.88it/s, now=None]
# t:  88% 211/241 [00:07<00:01, 25.36it/s, now=None]
# t:  89% 214/241 [00:07<00:01, 25.36it/s, now=None]
# t:  90% 217/241 [00:07<00:00, 24.85it/s, now=None]
# t:  91% 220/241 [00:07<00:00, 25.48it/s, now=None]
# t:  93% 223/241 [00:08<00:00, 26.11it/s, now=None]
# t:  94% 227/241 [00:08<00:00, 27.34it/s, now=None]
# t:  95% 230/241 [00:08<00:00, 27.16it/s, now=None]
# t:  97% 233/241 [00:08<00:00, 26.95it/s, now=None]
# t:  98% 236/241 [00:08<00:00, 27.26it/s, now=None]
# t:  99% 239/241 [00:08<00:00, 27.34it/s, now=None]
#                                                   Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 285, in ffmpeg_parse_infos
#     line = [l for l in lines if keyword in l][index]
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "reverse_video.py", line 75, in <module>
#     frames_folder_path, video_fps = extract_frames(video_file)
#   File "reverse_video.py", line 28, in extract_frames
#     video_clip = VideoFileClip(video_file)
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/VideoFileClip.py", line 91, in __init__
#     fps_source=fps_source)
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 36, in __init__
#     fps_source)
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 291, in ffmpeg_parse_infos
#     filename, infos))
# OSError: MoviePy error: failed to read the duration of file /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0_dolly-zoom-in.mp4.
# Here are the file infos returned by ffmpeg:
#
# ffmpeg version 4.2.2-static https://johnvansickle.com/ffmpeg/  Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 8 (Debian 8.3.0-6)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-debug --disable-ffplay --disable-indev=sndio --disable-outdev=sndio --cc=gcc --enable-fontconfig --enable-frei0r --enable-gnutls --enable-gmp --enable-libgme --enable-gray --enable-libaom --enable-libfribidi --enable-libass --enable-libvmaf --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librubberband --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libvorbis --enable-libopus --enable-libtheora --enable-libvidstab --enable-libvo-amrwbenc --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libdav1d --enable-libxvid --enable-libzvbi --enable-libzimg
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x62d4580] moov atom not found
# /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0_dolly-zoom-in.mp4: Invalid data found when processing input
# [2022-05-05 09:39:23,668] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 285, in ffmpeg_parse_infos
#     line = [l for l in lines if keyword in l][index]
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.7/dist-packages/flask_cors/extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.7/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/local/lib/python3.7/dist-packages/gradio/networking.py", line 90, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/gradio/networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "/usr/local/lib/python3.7/dist-packages/gradio/interface.py", line 350, in process
#     processed_input, return_duration=True)
#   File "/usr/local/lib/python3.7/dist-packages/gradio/interface.py", line 322, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-2-63f12e273e63>", line 105, in generate
#     clip1 = VideoFileClip(f"/content/drive/MyDrive/pixray/3d-photo-inpainting/video/image{i}_dolly-zoom-in.mp4")
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/VideoFileClip.py", line 91, in __init__
#     fps_source=fps_source)
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 36, in __init__
#     fps_source)
#   File "/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py", line 291, in ffmpeg_parse_infos
#     filename, infos))
# OSError: MoviePy error: failed to read the duration of file /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0_dolly-zoom-in.mp4.
# Here are the file infos returned by ffmpeg:
#
# ffmpeg version 4.2.2-static https://johnvansickle.com/ffmpeg/  Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 8 (Debian 8.3.0-6)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-debug --disable-ffplay --disable-indev=sndio --disable-outdev=sndio --cc=gcc --enable-fontconfig --enable-frei0r --enable-gnutls --enable-gmp --enable-libgme --enable-gray --enable-libaom --enable-libfribidi --enable-libass --enable-libvmaf --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librubberband --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libvorbis --enable-libopus --enable-libtheora --enable-libvidstab --enable-libvo-amrwbenc --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libdav1d --enable-libxvid --enable-libzvbi --enable-libzimg
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x73ea580] moov atom not found
# /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0_dolly-zoom-in.mp4: Invalid data found when processing input
# Moviepy - Done !
# Moviepy - video ready video/image0_dolly-zoom-in.mp4
# 100% 1/1 [09:27<00:00, 567.49s/it]
# Extracting video frames: 100% 181/181 [00:06<00:00, 29.53it/s]
# Saving the video with FPS: 30
# Moviepy - Building video /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0_dolly-zoom-in-inverted.mp4.
# Moviepy - Writing video /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0_dolly-zoom-in-inverted.mp4
#
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0_dolly-zoom-in-inverted.mp4
# Moviepy - Building video /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0.mp4.
# Moviepy - Writing video /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0.mp4
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0.mp4
# renamed '/content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0_dolly-zoom-in-inverted.mp4' -> '/content/drive/MyDrive/pixray/3d-photo-inpainting/results/result_testing/image0_dolly-zoom-in-inverted.mp4'
# renamed '/content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0_dolly-zoom-in.mp4' -> '/content/drive/MyDrive/pixray/3d-photo-inpainting/results/result_testing/image0_dolly-zoom-in.mp4'
# renamed '/content/drive/MyDrive/pixray/3d-photo-inpainting/video/image0.mp4' -> '/content/drive/MyDrive/pixray/3d-photo-inpainting/results/result_testing/image0.mp4'
# running on device 0
#   0% 0/1 [00:00<?, ?it/s]Current Source ==>  image1
# Running depth extraction at 1651743647.3348978
# BoostingMonocularDepth/inputs/*.png
# BoostingMonocularDepth/outputs/*.png
# /usr/local/lib/python3.7/dist-packages/paramiko/transport.py:236: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# device: cuda
# Namespace(Final=True, R0=False, R20=False, colorize_results=False, data_dir='inputs/', depthNet=0, max_res=inf, net_receptive_field_size=None, output_dir='outputs', output_resolution=1, pix2pixsize=1024, savepatchs=0, savewholeest=0)
# ----------------- Options ---------------
#                     Final: True                          	[default: False]
#                        R0: False
#                       R20: False
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./pix2pix/checkpoints
#          colorize_results: False
#                 crop_size: 672
#                  data_dir: inputs/                       	[default: None]
#                  dataroot: None
#              dataset_mode: depthmerge
#                  depthNet: 0                             	[default: None]
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#             generatevideo: None
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 2
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 672
#          max_dataset_size: 10000
#                   max_res: inf
#                     model: pix2pix4depth
#                n_layers_D: 3
#                      name: void
#                       ndf: 64
#                      netD: basic
#                      netG: unet_1024
#  net_receptive_field_size: None
#                       ngf: 64
#                no_dropout: False
#                   no_flip: False
#                      norm: none
#                  num_test: 50
#               num_threads: 4
#                output_dir: outputs                       	[default: None]
#                 output_nc: 1
#         output_resolution: None
#                     phase: test
#               pix2pixsize: None
#                preprocess: resize_and_crop
#                 savecrops: None
#              savewholeest: None
#            serial_batches: False
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
# initialize network with normal
# loading the model from ./pix2pix/checkpoints/mergemodel/latest_net_G.pth
# Loading weights:  midas/model.pt
# Using cache found in /root/.cache/torch/hub/facebookresearch_WSL-Images_main
# start processing
# processing image 0 : image1
# 	 wholeImage being processed in : 2112
#  	 	 DEBUG| GPU THRESHOLD REACHED 2112 ---> 1568
# Adjust factor is: 1.0
# Selecting patchs ...
# Target resolution:  (4224, 3122, 3)
# Dynamicly change merged-in resolution; scale: 0.17424242424242425
# 	 Resulted depthmap res will be : (736, 544)
# patchs to process: 58
# 	 processing patch 0 | [  0 151 535 535]
# 	 processing patch 1 | [ 20 120 496 496]
# 	 processing patch 2 | [ 33  84 468 468]
# 	 processing patch 3 | [ 92  92 452 452]
# 	 processing patch 4 | [ 92 142 452 452]
# 	 processing patch 5 | [ 92 192 452 452]
# 	 processing patch 6 | [ 92 243 452 452]
# 	 processing patch 7 | [  0 201 435 435]
# 	 processing patch 8 | [  0 251 435 435]
# 	 processing patch 9 | [  8  59 418 418]
# 	 processing patch 10 | [ 17 117 401 401]
# 	 processing patch 11 | [ 22 173 390 390]
# 	 processing patch 12 | [192 192 351 351]
# 	 processing patch 13 | [192 243 351 351]
# 	 processing patch 14 | [192 293 351 351]
# 	 processing patch 15 | [  0 100 335 335]
# 	 processing patch 16 | [  0 151 335 335]
# 	 processing patch 17 | [  0 301 335 335]
# 	 processing patch 18 | [  0 401 335 335]
# 	 processing patch 19 | [ 50 401 335 335]
# 	 processing patch 20 | [100 401 335 335]
# 	 processing patch 21 | [151 401 335 335]
# 	 processing patch 22 | [201 401 335 335]
# 	 processing patch 23 | [  6 206 323 323]
# 	 processing patch 24 | [  8 259 318 318]
# 	 processing patch 25 | [293 243 251 251]
# 	 processing patch 26 | [293 293 251 251]
# 	 processing patch 27 | [293 343 251 251]
# 	 processing patch 28 | [293 393 251 251]
# 	 processing patch 29 | [293 443 251 251]
# 	 processing patch 30 | [  0 201 234 234]
# 	 processing patch 31 | [  0 452 234 234]
# 	 processing patch 32 | [  0 502 234 234]
# 	 processing patch 33 | [ 50 502 234 234]
# 	 processing patch 34 | [100 502 234 234]
# 	 processing patch 35 | [151 502 234 234]
# 	 processing patch 36 | [201 502 234 234]
# 	 processing patch 37 | [251 502 234 234]
# 	 processing patch 38 | [301 502 234 234]
# 	 processing patch 39 | [  8  59 217 217]
# 	 processing patch 40 | [  8 259 217 217]
# 	 processing patch 41 | [ 11 162 212 212]
# 	 processing patch 42 | [ 20  20 195 195]
# 	 processing patch 43 | [ 25 125 184 184]
# 	 processing patch 44 | [ 78 128 178 178]
# 	 processing patch 45 | [ 39 340 156 156]
# 	 processing patch 46 | [393 293 151 151]
# 	 processing patch 47 | [393 343 151 151]
# 	 processing patch 48 | [393 393 151 151]
# 	 processing patch 49 | [393 443 151 151]
# 	 processing patch 50 | [393 493 151 151]
# 	 processing patch 51 | [393 544 151 151]
# 	 processing patch 52 | [ 95  45 145 145]
# 	 processing patch 53 | [  0  50 134 134]
# 	 processing patch 54 | [  0 100 134 134]
# 	 processing patch 55 | [  0 552 134 134]
# 	 processing patch 56 | [ 50   0 134 134]
# 	 processing patch 57 | [ 50 401 134 134]
# finished
# Start Running 3D_Photo ...
# Loading edge model at 1651743718.12335
# Loading depth model at 1651743720.737155
# Loading rgb model at 1651743721.5993638
# Writing depth ply (and basically doing everything) at 1651743722.3919277
# Making video at 1651744087.2398417
# fov: 53.13010235415598
# Moviepy - Building video video/image1_dolly-zoom-in.mp4.
# Moviepy - Writing video video/image1_dolly-zoom-in.mp4
#
#   0% 0/1 [08:23<?, ?it/s]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   2% 5/241 [00:00<00:05, 45.88it/s, now=None]
# t:   4% 10/241 [00:00<00:04, 46.80it/s, now=None]
# t:   6% 15/241 [00:00<00:04, 47.11it/s, now=None]
# t:   8% 20/241 [00:00<00:04, 47.46it/s, now=None]
# t:  10% 25/241 [00:00<00:04, 47.28it/s, now=None]
# t:  12% 30/241 [00:00<00:04, 46.58it/s, now=None]
# t:  15% 35/241 [00:00<00:04, 45.62it/s, now=None]
# t:  17% 40/241 [00:00<00:04, 45.81it/s, now=None]
# t:  19% 45/241 [00:00<00:04, 45.95it/s, now=None]
# t:  21% 50/241 [00:01<00:07, 27.13it/s, now=None]
# t:  22% 54/241 [00:01<00:06, 27.78it/s, now=None]
# t:  24% 58/241 [00:01<00:06, 26.78it/s, now=None]
# t:  26% 62/241 [00:01<00:06, 28.35it/s, now=None]
# t:  27% 66/241 [00:01<00:06, 28.15it/s, now=None]
# t:  29% 70/241 [00:02<00:06, 28.25it/s, now=None]
# t:  31% 74/241 [00:02<00:05, 29.09it/s, now=None]
# t:  32% 78/241 [00:02<00:05, 28.63it/s, now=None]
# t:  34% 81/241 [00:02<00:05, 27.87it/s, now=None]
# t:  35% 85/241 [00:02<00:05, 28.30it/s, now=None]
# t:  37% 88/241 [00:02<00:05, 27.87it/s, now=None]
# t:  38% 91/241 [00:02<00:05, 26.99it/s, now=None]
# t:  39% 94/241 [00:02<00:05, 27.48it/s, now=None]
# t:  40% 97/241 [00:02<00:05, 27.56it/s, now=None]
# t:  41% 100/241 [00:03<00:05, 26.93it/s, now=None]
# t:  43% 104/241 [00:03<00:04, 28.56it/s, now=None]
# t:  45% 108/241 [00:03<00:04, 30.98it/s, now=None]
# t:  46% 112/241 [00:03<00:04, 29.60it/s, now=None]
# t:  48% 116/241 [00:03<00:04, 29.77it/s, now=None]
# t:  50% 120/241 [00:03<00:04, 29.57it/s, now=None]
# t:  51% 124/241 [00:03<00:03, 29.62it/s, now=None]
# t:  53% 127/241 [00:04<00:03, 29.50it/s, now=None]
# t:  54% 130/241 [00:04<00:03, 27.86it/s, now=None]
# t:  55% 133/241 [00:04<00:03, 27.31it/s, now=None]
# t:  56% 136/241 [00:04<00:03, 28.01it/s, now=None]
# t:  58% 140/241 [00:04<00:03, 29.11it/s, now=None]
# t:  59% 143/241 [00:04<00:03, 27.99it/s, now=None]
# t:  61% 146/241 [00:04<00:03, 27.86it/s, now=None]
# t:  62% 149/241 [00:04<00:03, 27.98it/s, now=None]
# t:  63% 153/241 [00:04<00:03, 28.24it/s, now=None]
# t:  65% 156/241 [00:05<00:03, 28.21it/s, now=None]
# t:  66% 160/241 [00:05<00:02, 29.06it/s, now=None]
# t:  68% 164/241 [00:05<00:02, 30.88it/s, now=None]
# t:  70% 168/241 [00:05<00:02, 29.50it/s, now=None]
# t:  71% 171/241 [00:05<00:02, 28.63it/s, now=None]
# t:  73% 175/241 [00:05<00:02, 29.64it/s, now=None]
# t:  74% 178/241 [00:05<00:02, 29.66it/s, now=None]
# t:  75% 181/241 [00:05<00:02, 29.03it/s, now=None]
# t:  76% 184/241 [00:05<00:01, 28.72it/s, now=None]
# t:  78% 187/241 [00:06<00:01, 28.87it/s, now=None]
# t:  79% 191/241 [00:06<00:01, 29.88it/s, now=None]
# t:  80% 194/241 [00:06<00:01, 29.73it/s, now=None]
# t:  82% 197/241 [00:06<00:01, 29.67it/s, now=None]
# t:  83% 200/241 [00:06<00:01, 29.51it/s, now=None]
# t:  85% 204/241 [00:06<00:01, 30.72it/s, now=None]
# t:  86% 208/241 [00:06<00:01, 29.43it/s, now=None]
# t:  88% 211/241 [00:06<00:01, 29.39it/s, now=None]
# t:  89% 214/241 [00:07<00:00, 29.39it/s, now=None]
# t:  90% 217/241 [00:07<00:00, 28.94it/s, now=None]
# t:  91% 220/241 [00:07<00:00, 28.65it/s, now=None]
# t:  93% 224/241 [00:07<00:00, 29.24it/s, now=None]
# t:  95% 228/241 [00:07<00:00, 29.70it/s, now=None]
# t:  96% 231/241 [00:07<00:00, 28.64it/s, now=None]
# t:  98% 235/241 [00:07<00:00, 28.78it/s, now=None]
# t:  99% 238/241 [00:07<00:00, 29.04it/s, now=None]
# t: 100% 241/241 [00:07<00:00, 28.52it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/image1_dolly-zoom-in.mp4
# 100% 1/1 [08:33<00:00, 513.14s/it]
# Extracting video frames: 100% 181/181 [00:06<00:00, 28.43it/s]
# Saving the video with FPS: 30
# Moviepy - Building video /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image1_dolly-zoom-in-inverted.mp4.
# Moviepy - Writing video /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image1_dolly-zoom-in-inverted.mp4
#
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image1_dolly-zoom-in-inverted.mp4
# Moviepy - Building video /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image1.mp4.
# Moviepy - Writing video /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image1.mp4
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/pixray/3d-photo-inpainting/video/image1.mp4
# renamed '/content/drive/MyDrive/pixray/3d-photo-inpainting/video/image1_dolly-zoom-in-inverted.mp4' -> '/content/drive/MyDrive/pixray/3d-photo-inpainting/results/result_testing/image1_dolly-zoom-in-inverted.mp4'
# renamed '/content/drive/MyDrive/pixray/3d-photo-inpainting/video/image1_dolly-zoom-in.mp4' -> '/content/drive/MyDrive/pixray/3d-photo-inpainting/results/result_testing/image1_dolly-zoom-in.mp4'
# renamed '/content/drive/MyDrive/pixray/3d-photo-inpainting/video/image1.mp4' -> '/content/drive/MyDrive/pixray/3d-photo-inpainting/results/result_testing/image1.mp4'
# [2022-05-05 09:50:40,384] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.7/dist-packages/flask_cors/extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.7/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/local/lib/python3.7/dist-packages/gradio/networking.py", line 90, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/gradio/networking.py", line 180, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "/usr/local/lib/python3.7/dist-packages/gradio/interface.py", line 352, in process
#     predictions[i]) if predictions[i] is not None else None for i, output_component in enumerate(self.output_components)]
#   File "/usr/local/lib/python3.7/dist-packages/gradio/interface.py", line 352, in <listcomp>
#     predictions[i]) if predictions[i] is not None else None for i, output_component in enumerate(self.output_components)]
#   File "/usr/local/lib/python3.7/dist-packages/gradio/outputs.py", line 248, in postprocess
#     "data": processing_utils.encode_file_to_base64(y, type="video")
#   File "/usr/local/lib/python3.7/dist-packages/gradio/processing_utils.py", line 24, in encode_file_to_base64
#     with open(f, "rb") as file:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/pixray/3d-photo-inpainting/video/image1.mp4'

# %% [markdown]
# # Helper

# %%
# %%writefile /content/drive/MyDrive/pixray/3d-photo-inpainting/reverse_video.py

from moviepy.editor import VideoFileClip, ImageSequenceClip
import numpy as np
import os
from datetime import timedelta, datetime
from glob import glob
from tqdm import tqdm
import shutil

# i.e if video of duration 30 seconds, saves 10 frame per second = 300 frames saved in total
SAVING_FRAMES_PER_SECOND = 30

def format_timedelta(td):
    """Utility function to format timedelta objects in a cool way (e.g 00:00:20.05) 
    omitting microseconds and retaining milliseconds"""
    result = str(td)
    try:
        result, ms = result.split(".")
    except ValueError:
        return result + ".00".replace(":", "-")
    ms = int(ms)
    ms = round(ms / 1e4)
    return f"{result}.{ms:02}".replace(":", "-")


def extract_frames(video_file, verbose=1):
    # load the video clip
    video_clip = VideoFileClip(video_file)
    # make a folder by the name of the video file
    filename, _ = os.path.splitext(video_file)
    if not os.path.isdir(filename):
        os.mkdir(filename)
    # if the SAVING_FRAMES_PER_SECOND is above video FPS, then set it to FPS (as maximum)
    saving_frames_per_second = min(video_clip.fps, SAVING_FRAMES_PER_SECOND)
    # if SAVING_FRAMES_PER_SECOND is set to 0, step is 1/fps, else 1/SAVING_FRAMES_PER_SECOND
    step = 1 / video_clip.fps if saving_frames_per_second == 0 else 1 / saving_frames_per_second
    iteration = np.arange(0, video_clip.duration, step)
    if verbose:
        iteration = tqdm(iteration, desc="Extracting video frames")
    # iterate over each possible frame
    for current_duration in iteration:
        # format the file name and save it
        frame_duration_formatted = format_timedelta(timedelta(seconds=current_duration)).replace(":", "-")
        frame_filename = os.path.join(filename, f"frame{frame_duration_formatted}.jpg")
        # save the frame with the current duration
        video_clip.save_frame(frame_filename, current_duration)
    return filename, video_clip.fps



def reverse_video(frames_path, video_fps, remove_extracted_frames=True):
    frame_files = glob(os.path.join(frames_path, "*"))
    # sort by duration in descending order
    frame_files = sorted(frame_files, key=lambda d: datetime.strptime(d.split("frame")[1], "%H-%M-%S.%f.jpg"), reverse=True)
    # calculate the FPS, getting the minimum between the original FPS and the parameter we set
    saving_frames_per_second = min(video_fps, SAVING_FRAMES_PER_SECOND)
    if saving_frames_per_second == 0:
        # if the parameter is set to 0, automatically set it to the original video fps
        saving_frames_per_second = video_fps
    print("Saving the video with FPS:", saving_frames_per_second)
    # load the frames into a image sequence clip (MoviePy)
    image_sequence_clip = ImageSequenceClip(frame_files, fps=saving_frames_per_second)
    # write the video file to disk
    output_filename = f"{frames_path}-inverted.mp4"
    image_sequence_clip.write_videofile(output_filename)
    if remove_extracted_frames:
        # if set to True, then remove the folder that contain the extracted frames
        shutil.rmtree(frames_path)



if __name__ == "__main__":
    import sys
    video_file = sys.argv[1]
    frames_folder_path, video_fps = extract_frames(video_file)
    reverse_video(frames_folder_path, video_fps=video_fps)
# Out:
# Writing /content/drive/MyDrive/pixray/3d-photo-inpainting/reverse_video.py

# %%
filename = '/content/drive/MyDrive/pixray/3d-photo-inpainting/video/final_dolly-zoom-in.mp4' #@param{type:'string'}
# !python /content/reverse_video.py {filename}
# Out:
# Extracting video frames: 100% 181/181 [00:03<00:00, 48.15it/s]
# Saving the video with FPS: 30
# Moviepy - Building video /content/drive/MyDrive/pixray/3d-photo-inpainting/video/final_dolly-zoom-in-inverted.mp4.
# Moviepy - Writing video /content/drive/MyDrive/pixray/3d-photo-inpainting/video/final_dolly-zoom-in-inverted.mp4
#
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/pixray/3d-photo-inpainting/video/final_dolly-zoom-in-inverted.mp4

# %%
# Import everything needed to edit video clips
from moviepy.editor import *
 
# loading video dsa gfg intro video
clip1 = VideoFileClip("/content/drive/MyDrive/pixray/3d-photo-inpainting/video/final_dolly-zoom-in.mp4")
clip2 = VideoFileClip("/content/drive/MyDrive/pixray/3d-photo-inpainting/video/final_dolly-zoom-in-inverted.mp4") 

# concatenating both the clips
final = concatenate_videoclips([clip1,clip2,clip1,clip2,clip1,clip2])
#writing the video into a file / saving the combined video
final.write_videofile("/content/merged.mp4")
# Out:
# Moviepy - Building video /content/merged.mp4.
# Moviepy - Writing video /content/merged.mp4
# Moviepy - Done !
# Moviepy - video ready /content/merged.mp4

# %%
# !ffmpeg -stream_loop 5 -i /content/merged.mp4 -c copy /content/output.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/merged.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:12.08, start: 0.000000, bitrate: 661 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 792x960, 657 kb/s, 40 fps, 40 tbr, 10240 tbn, 80 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Output #0, mp4, to '/content/output.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 792x960, q=2-31, 657 kb/s, 40 fps, 40 tbr, 10240 tbn, 10240 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame= 1648 fps=0.0 q=-1.0 Lsize=    3508kB time=00:04:32.25 bitrate= 105.6kbits/s speed=3.12e+04x
# video:3488kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.580743%

# %%
# !python main.py --config argument.yml
# Out:
# running on device 0
#   0% 0/2 [00:00<?, ?it/s]Current Source ==>  image0
# Running depth extraction at 1648581130.2973347
# BoostingMonocularDepth/inputs/*.png
# BoostingMonocularDepth/outputs/*.png
# device: cuda
# Namespace(Final=True, R0=False, R20=False, colorize_results=False, data_dir='inputs/', depthNet=0, max_res=inf, net_receptive_field_size=None, output_dir='outputs', output_resolution=1, pix2pixsize=1024, savepatchs=0, savewholeest=0)
# ----------------- Options ---------------
#                     Final: True                          	[default: False]
#                        R0: False
#                       R20: False
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./pix2pix/checkpoints
#          colorize_results: False
#                 crop_size: 672
#                  data_dir: inputs/                       	[default: None]
#                  dataroot: None
#              dataset_mode: depthmerge
#                  depthNet: 0                             	[default: None]
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#             generatevideo: None
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 2
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 672
#          max_dataset_size: 10000
#                   max_res: inf
#                     model: pix2pix4depth
#                n_layers_D: 3
#                      name: void
#                       ndf: 64
#                      netD: basic
#                      netG: unet_1024
#  net_receptive_field_size: None
#                       ngf: 64
#                no_dropout: False
#                   no_flip: False
#                      norm: none
#                  num_test: 50
#               num_threads: 4
#                output_dir: outputs                       	[default: None]
#                 output_nc: 1
#         output_resolution: None
#                     phase: test
#               pix2pixsize: None
#                preprocess: resize_and_crop
#                 savecrops: None
#              savewholeest: None
#            serial_batches: False
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
# initialize network with normal
# loading the model from ./pix2pix/checkpoints/mergemodel/latest_net_G.pth
# Loading weights:  midas/model.pt
# Using cache found in /root/.cache/torch/hub/facebookresearch_WSL-Images_main
# start processing
# processing image 0 : image0
# 	 wholeImage being processed in : 2112
#  	 	 DEBUG| GPU THRESHOLD REACHED 2112 ---> 1568
# Adjust factor is: 1.0
# Selecting patchs ...
# Target resolution:  (4224, 3122, 3)
# Dynamicly change merged-in resolution; scale: 0.17424242424242425
# 	 Resulted depthmap res will be : (736, 544)
# patchs to process: 66
# 	 processing patch 0 | [  0 201 535 535]
# 	 processing patch 1 | [ 92 192 452 452]
# 	 processing patch 2 | [ 92 243 452 452]
# 	 processing patch 3 | [  0 251 435 435]
# 	 processing patch 4 | [  0 301 435 435]
# 	 processing patch 5 | [ 50 301 435 435]
# 	 processing patch 6 | [100 301 435 435]
# 	 processing patch 7 | [ 36  86 362 362]
# 	 processing patch 8 | [192 243 351 351]
# 	 processing patch 9 | [192 293 351 351]
# 	 processing patch 10 | [192 343 351 351]
# 	 processing patch 11 | [  0 351 335 335]
# 	 processing patch 12 | [  0 401 335 335]
# 	 processing patch 13 | [ 50  50 335 335]
# 	 processing patch 14 | [ 50 401 335 335]
# 	 processing patch 15 | [100 401 335 335]
# 	 processing patch 16 | [151 401 335 335]
# 	 processing patch 17 | [201 401 335 335]
# 	 processing patch 18 | [ 64  14 307 307]
# 	 processing patch 19 | [ 20  70 296 296]
# 	 processing patch 20 | [120  70 296 296]
# 	 processing patch 21 | [123  22 290 290]
# 	 processing patch 22 | [ 31  31 273 273]
# 	 processing patch 23 | [137 137 262 262]
# 	 processing patch 24 | [187  86 262 262]
# 	 processing patch 25 | [293 243 251 251]
# 	 processing patch 26 | [293 293 251 251]
# 	 processing patch 27 | [293 343 251 251]
# 	 processing patch 28 | [293 393 251 251]
# 	 processing patch 29 | [293 443 251 251]
# 	 processing patch 30 | [  0 301 234 234]
# 	 processing patch 31 | [  0 351 234 234]
# 	 processing patch 32 | [  0 401 234 234]
# 	 processing patch 33 | [  0 452 234 234]
# 	 processing patch 34 | [ 50 502 234 234]
# 	 processing patch 35 | [100   0 234 234]
# 	 processing patch 36 | [100 502 234 234]
# 	 processing patch 37 | [151   0 234 234]
# 	 processing patch 38 | [251 502 234 234]
# 	 processing patch 39 | [301 502 234 234]
# 	 processing patch 40 | [206 156 223 223]
# 	 processing patch 41 | [ 59   8 217 217]
# 	 processing patch 42 | [ 11 262 212 212]
# 	 processing patch 43 | [217  67 201 201]
# 	 processing patch 44 | [ 20 521 195 195]
# 	 processing patch 45 | [ 31 181 173 173]
# 	 processing patch 46 | [237 237 162 162]
# 	 processing patch 47 | [ 39 240 156 156]
# 	 processing patch 48 | [340  39 156 156]
# 	 processing patch 49 | [243 293 151 151]
# 	 processing patch 50 | [393  42 151 151]
# 	 processing patch 51 | [393 293 151 151]
# 	 processing patch 52 | [393 343 151 151]
# 	 processing patch 53 | [393 393 151 151]
# 	 processing patch 54 | [393 443 151 151]
# 	 processing patch 55 | [393 493 151 151]
# 	 processing patch 56 | [393 544 151 151]
# 	 processing patch 57 | [  0 251 134 134]
# 	 processing patch 58 | [  0 301 134 134]
# 	 processing patch 59 | [  0 351 134 134]
# 	 processing patch 60 | [  0 401 134 134]
# 	 processing patch 61 | [  0 452 134 134]
# 	 processing patch 62 | [  0 502 134 134]
# 	 processing patch 63 | [251  50 134 134]
# 	 processing patch 64 | [351   0 134 134]
# 	 processing patch 65 | [401   0 134 134]
# finished
# Start Running 3D_Photo ...
# Loading edge model at 1648581210.9119947
# Loading depth model at 1648581213.1366959
# Loading rgb model at 1648581213.9584837
# Writing depth ply (and basically doing everything) at 1648581214.7307763
# Writing mesh file mesh/image0.ply ...
# Making video at 1648581680.9175913
# fov: 53.13010235415598
# tcmalloc: large alloc 1354194944 bytes == 0x560aeeab0000 @  0x7f582c54a1e7 0x7f5829e9b0ce 0x7f5829ef1cf5 0x7f5829ef1e08 0x7f5829f840b9 0x7f5829f86a25 0x56096963a419 0x5609695c1e5c 0x5609695c0a2e 0x56096955388a 0x5609695c2719 0x5609695537aa 0x5609695c1b4f 0x5609695c0a2e 0x56096955388a 0x5609695c2719 0x560969492d14 0x5609695c2ff1 0x5609695c0a2e 0x56096955388a 0x5609695c5d30 0x5609695537aa 0x5609695c1b4f 0x5609695c0a2e 0x56096955388a 0x5609695c1b4f 0x5609695c0a2e 0x56096955388a 0x5609695c2719 0x5609695c0cdd 0x56096955388a
# Moviepy - Building video video/image0_dolly-zoom-in.mp4.
# Moviepy - Writing video video/image0_dolly-zoom-in.mp4
#
#   0% 0/2 [10:15<?, ?it/s]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   2% 6/241 [00:00<00:04, 55.62it/s, now=None]
# t:   5% 12/241 [00:00<00:04, 56.02it/s, now=None]
# t:   7% 18/241 [00:00<00:04, 55.64it/s, now=None]
# t:  10% 24/241 [00:00<00:03, 55.75it/s, now=None]
# t:  12% 30/241 [00:00<00:03, 55.61it/s, now=None]
# t:  15% 36/241 [00:00<00:03, 55.28it/s, now=None]
# t:  17% 42/241 [00:00<00:03, 55.50it/s, now=None]
# t:  20% 48/241 [00:01<00:06, 31.40it/s, now=None]
# t:  22% 53/241 [00:01<00:05, 33.97it/s, now=None]
# t:  24% 58/241 [00:01<00:05, 34.24it/s, now=None]
# t:  26% 63/241 [00:01<00:05, 34.52it/s, now=None]
# t:  28% 67/241 [00:01<00:04, 35.29it/s, now=None]
# t:  29% 71/241 [00:01<00:04, 35.38it/s, now=None]
# t:  31% 75/241 [00:01<00:04, 35.58it/s, now=None]
# t:  33% 79/241 [00:01<00:04, 35.40it/s, now=None]
# t:  34% 83/241 [00:02<00:04, 34.20it/s, now=None]
# t:  36% 87/241 [00:02<00:04, 34.64it/s, now=None]
# t:  38% 91/241 [00:02<00:04, 34.75it/s, now=None]
# t:  39% 95/241 [00:02<00:04, 34.66it/s, now=None]
# t:  41% 99/241 [00:02<00:04, 34.81it/s, now=None]
# t:  43% 103/241 [00:02<00:03, 34.57it/s, now=None]
# t:  44% 107/241 [00:02<00:03, 34.86it/s, now=None]
# t:  46% 111/241 [00:02<00:03, 33.35it/s, now=None]
# t:  48% 115/241 [00:03<00:03, 33.43it/s, now=None]
# t:  49% 119/241 [00:03<00:03, 33.75it/s, now=None]
# t:  51% 123/241 [00:03<00:03, 33.66it/s, now=None]
# t:  53% 127/241 [00:03<00:03, 33.98it/s, now=None]
# t:  54% 131/241 [00:03<00:03, 33.81it/s, now=None]
# t:  56% 135/241 [00:03<00:03, 34.87it/s, now=None]
# t:  58% 139/241 [00:03<00:02, 34.05it/s, now=None]
# t:  59% 143/241 [00:03<00:02, 35.19it/s, now=None]
# t:  61% 147/241 [00:03<00:02, 34.98it/s, now=None]
# t:  63% 151/241 [00:04<00:02, 35.41it/s, now=None]
# t:  64% 155/241 [00:04<00:02, 34.95it/s, now=None]
# t:  66% 159/241 [00:04<00:02, 35.06it/s, now=None]
# t:  68% 163/241 [00:04<00:02, 35.84it/s, now=None]
# t:  69% 167/241 [00:04<00:02, 35.66it/s, now=None]
# t:  71% 171/241 [00:04<00:01, 36.11it/s, now=None]
# t:  73% 175/241 [00:04<00:01, 35.82it/s, now=None]
# t:  74% 179/241 [00:04<00:01, 35.79it/s, now=None]
# t:  76% 183/241 [00:04<00:01, 35.85it/s, now=None]
# t:  78% 187/241 [00:05<00:01, 34.86it/s, now=None]
# t:  79% 191/241 [00:05<00:01, 34.96it/s, now=None]
# t:  81% 195/241 [00:05<00:01, 35.14it/s, now=None]
# t:  83% 199/241 [00:05<00:01, 34.83it/s, now=None]
# t:  84% 203/241 [00:05<00:01, 34.45it/s, now=None]
# t:  86% 207/241 [00:05<00:00, 34.81it/s, now=None]
# t:  88% 211/241 [00:05<00:00, 35.53it/s, now=None]
# t:  89% 215/241 [00:05<00:00, 35.51it/s, now=None]
# t:  91% 219/241 [00:05<00:00, 35.24it/s, now=None]
# t:  93% 223/241 [00:06<00:00, 34.99it/s, now=None]
# t:  94% 227/241 [00:06<00:00, 36.30it/s, now=None]
# t:  96% 231/241 [00:06<00:00, 36.11it/s, now=None]
# t:  98% 235/241 [00:06<00:00, 36.86it/s, now=None]
# t:  99% 239/241 [00:06<00:00, 36.37it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/image0_dolly-zoom-in.mp4
# Moviepy - Building video video/image0_zoom-in.mp4.
# Moviepy - Writing video video/image0_zoom-in.mp4
#
#   0% 0/2 [11:22<?, ?it/s]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   2% 6/241 [00:00<00:04, 55.73it/s, now=None]
# t:   5% 12/241 [00:00<00:04, 54.80it/s, now=None]
# t:   7% 18/241 [00:00<00:04, 53.91it/s, now=None]
# t:  10% 24/241 [00:00<00:03, 54.82it/s, now=None]
# t:  12% 30/241 [00:00<00:03, 54.76it/s, now=None]
# t:  15% 36/241 [00:00<00:03, 55.00it/s, now=None]
# t:  17% 42/241 [00:00<00:03, 55.32it/s, now=None]
# t:  20% 48/241 [00:01<00:05, 32.39it/s, now=None]
# t:  22% 53/241 [00:01<00:05, 34.96it/s, now=None]
# t:  24% 58/241 [00:01<00:05, 33.85it/s, now=None]
# t:  26% 62/241 [00:01<00:05, 34.03it/s, now=None]
# t:  27% 66/241 [00:01<00:05, 33.77it/s, now=None]
# t:  29% 70/241 [00:01<00:05, 33.65it/s, now=None]
# t:  31% 74/241 [00:01<00:04, 33.86it/s, now=None]
# t:  32% 78/241 [00:01<00:04, 33.88it/s, now=None]
# t:  34% 82/241 [00:02<00:04, 34.07it/s, now=None]
# t:  36% 86/241 [00:02<00:04, 34.20it/s, now=None]
# t:  37% 90/241 [00:02<00:04, 34.79it/s, now=None]
# t:  39% 94/241 [00:02<00:04, 34.85it/s, now=None]
# t:  41% 98/241 [00:02<00:04, 35.59it/s, now=None]
# t:  42% 102/241 [00:02<00:03, 35.43it/s, now=None]
# t:  44% 106/241 [00:02<00:03, 36.34it/s, now=None]
# t:  46% 110/241 [00:02<00:03, 36.45it/s, now=None]
# t:  47% 114/241 [00:02<00:03, 36.48it/s, now=None]
# t:  49% 118/241 [00:03<00:03, 36.60it/s, now=None]
# t:  51% 122/241 [00:03<00:03, 36.84it/s, now=None]
# t:  52% 126/241 [00:03<00:03, 35.76it/s, now=None]
# t:  54% 130/241 [00:03<00:03, 35.66it/s, now=None]
# t:  56% 134/241 [00:03<00:03, 34.77it/s, now=None]
# t:  57% 138/241 [00:03<00:02, 34.87it/s, now=None]
# t:  59% 142/241 [00:03<00:02, 35.70it/s, now=None]
# t:  61% 146/241 [00:03<00:02, 35.91it/s, now=None]
# t:  62% 150/241 [00:03<00:02, 35.57it/s, now=None]
# t:  64% 154/241 [00:04<00:02, 34.98it/s, now=None]
# t:  66% 158/241 [00:04<00:02, 34.46it/s, now=None]
# t:  67% 162/241 [00:04<00:02, 35.58it/s, now=None]
# t:  69% 166/241 [00:04<00:02, 35.70it/s, now=None]
# t:  71% 170/241 [00:04<00:01, 35.69it/s, now=None]
# t:  72% 174/241 [00:04<00:01, 35.88it/s, now=None]
# t:  74% 178/241 [00:04<00:01, 35.83it/s, now=None]
# t:  76% 182/241 [00:04<00:01, 36.68it/s, now=None]
# t:  77% 186/241 [00:04<00:01, 36.59it/s, now=None]
# t:  79% 190/241 [00:05<00:01, 36.21it/s, now=None]
# t:  80% 194/241 [00:05<00:01, 36.25it/s, now=None]
# t:  82% 198/241 [00:05<00:01, 35.55it/s, now=None]
# t:  84% 202/241 [00:05<00:01, 35.24it/s, now=None]
# t:  85% 206/241 [00:05<00:00, 35.11it/s, now=None]
# t:  87% 210/241 [00:05<00:00, 35.18it/s, now=None]
# t:  89% 214/241 [00:05<00:00, 35.04it/s, now=None]
# t:  90% 218/241 [00:05<00:00, 35.44it/s, now=None]
# t:  92% 222/241 [00:06<00:00, 35.01it/s, now=None]
# t:  94% 226/241 [00:06<00:00, 34.64it/s, now=None]
# t:  95% 230/241 [00:06<00:00, 35.00it/s, now=None]
# t:  97% 234/241 [00:06<00:00, 34.11it/s, now=None]
# t:  99% 238/241 [00:06<00:00, 34.00it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/image0_zoom-in.mp4
# Moviepy - Building video video/image0_circle.mp4.
# Moviepy - Writing video video/image0_circle.mp4
#
#   0% 0/2 [12:28<?, ?it/s]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   2% 6/241 [00:00<00:04, 55.15it/s, now=None]
# t:   5% 12/241 [00:00<00:04, 55.29it/s, now=None]
# t:   7% 18/241 [00:00<00:04, 55.49it/s, now=None]
# t:  10% 24/241 [00:00<00:03, 55.71it/s, now=None]
# t:  12% 30/241 [00:00<00:03, 55.62it/s, now=None]
# t:  15% 36/241 [00:00<00:03, 55.89it/s, now=None]
# t:  17% 42/241 [00:00<00:03, 55.48it/s, now=None]
# t:  20% 48/241 [00:01<00:07, 27.42it/s, now=None]
# t:  22% 53/241 [00:01<00:06, 29.88it/s, now=None]
# t:  24% 58/241 [00:01<00:05, 30.95it/s, now=None]
# t:  26% 62/241 [00:01<00:05, 31.66it/s, now=None]
# t:  27% 66/241 [00:01<00:05, 32.49it/s, now=None]
# t:  29% 70/241 [00:01<00:05, 31.25it/s, now=None]
# t:  31% 74/241 [00:01<00:05, 32.37it/s, now=None]
# t:  32% 78/241 [00:02<00:05, 31.93it/s, now=None]
# t:  34% 82/241 [00:02<00:04, 33.39it/s, now=None]
# t:  36% 86/241 [00:02<00:04, 33.75it/s, now=None]
# t:  37% 90/241 [00:02<00:04, 33.74it/s, now=None]
# t:  39% 94/241 [00:02<00:04, 32.75it/s, now=None]
# t:  41% 98/241 [00:02<00:04, 33.61it/s, now=None]
# t:  42% 102/241 [00:02<00:04, 33.56it/s, now=None]
# t:  44% 106/241 [00:02<00:04, 33.41it/s, now=None]
# t:  46% 110/241 [00:03<00:04, 28.82it/s, now=None]
# t:  47% 114/241 [00:03<00:04, 30.61it/s, now=None]
# t:  49% 118/241 [00:03<00:03, 31.95it/s, now=None]
# t:  51% 122/241 [00:03<00:03, 33.08it/s, now=None]
# t:  52% 126/241 [00:03<00:03, 30.94it/s, now=None]
# t:  54% 130/241 [00:03<00:03, 32.16it/s, now=None]
# t:  56% 134/241 [00:03<00:03, 33.46it/s, now=None]
# t:  57% 138/241 [00:03<00:03, 33.44it/s, now=None]
# t:  59% 142/241 [00:04<00:03, 30.87it/s, now=None]
# t:  61% 146/241 [00:04<00:02, 32.09it/s, now=None]
# t:  62% 150/241 [00:04<00:02, 33.01it/s, now=None]
# t:  64% 154/241 [00:04<00:02, 33.72it/s, now=None]
# t:  66% 158/241 [00:04<00:02, 30.45it/s, now=None]
# t:  67% 162/241 [00:04<00:02, 31.15it/s, now=None]
# t:  69% 166/241 [00:04<00:02, 32.29it/s, now=None]
# t:  71% 170/241 [00:04<00:02, 32.28it/s, now=None]
# t:  72% 174/241 [00:05<00:02, 33.16it/s, now=None]
# t:  74% 178/241 [00:05<00:01, 33.28it/s, now=None]
# t:  76% 182/241 [00:05<00:01, 32.91it/s, now=None]
# t:  77% 186/241 [00:05<00:01, 33.16it/s, now=None]
# t:  79% 190/241 [00:05<00:01, 34.20it/s, now=None]
# t:  80% 194/241 [00:05<00:01, 34.37it/s, now=None]
# t:  82% 198/241 [00:05<00:01, 33.26it/s, now=None]
# t:  84% 202/241 [00:05<00:01, 33.32it/s, now=None]
# t:  85% 206/241 [00:06<00:01, 33.29it/s, now=None]
# t:  87% 210/241 [00:06<00:01, 30.82it/s, now=None]
# t:  89% 214/241 [00:06<00:00, 31.50it/s, now=None]
# t:  90% 218/241 [00:06<00:00, 31.54it/s, now=None]
# t:  92% 222/241 [00:06<00:00, 31.52it/s, now=None]
# t:  94% 226/241 [00:06<00:00, 31.90it/s, now=None]
# t:  95% 230/241 [00:06<00:00, 32.83it/s, now=None]
# t:  97% 234/241 [00:06<00:00, 33.45it/s, now=None]
# t:  99% 238/241 [00:07<00:00, 33.24it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/image0_circle.mp4
# Moviepy - Building video video/image0_swing.mp4.
# Moviepy - Writing video video/image0_swing.mp4
#
#   0% 0/2 [13:33<?, ?it/s]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   1% 2/241 [00:00<00:56,  4.26it/s, now=None]
# t:   3% 7/241 [00:00<00:16, 14.37it/s, now=None]
# t:   5% 13/241 [00:00<00:09, 24.73it/s, now=None]
# t:   8% 19/241 [00:00<00:06, 32.81it/s, now=None]
# t:  10% 25/241 [00:00<00:05, 38.94it/s, now=None]
# t:  13% 31/241 [00:01<00:04, 43.46it/s, now=None]
# t:  15% 37/241 [00:01<00:04, 46.60it/s, now=None]
# t:  18% 43/241 [00:01<00:04, 49.16it/s, now=None]
# t:  20% 49/241 [00:01<00:06, 28.47it/s, now=None]
# t:  22% 54/241 [00:01<00:06, 30.84it/s, now=None]
# t:  24% 59/241 [00:01<00:05, 31.62it/s, now=None]
# t:  26% 63/241 [00:02<00:05, 32.36it/s, now=None]
# t:  28% 67/241 [00:02<00:05, 32.27it/s, now=None]
# t:  29% 71/241 [00:02<00:05, 33.12it/s, now=None]
# t:  31% 75/241 [00:02<00:04, 34.08it/s, now=None]
# t:  33% 79/241 [00:02<00:04, 34.83it/s, now=None]
# t:  34% 83/241 [00:02<00:04, 34.66it/s, now=None]
# t:  36% 87/241 [00:02<00:04, 33.07it/s, now=None]
# t:  38% 91/241 [00:02<00:04, 33.79it/s, now=None]
# t:  39% 95/241 [00:02<00:04, 31.97it/s, now=None]
# t:  41% 99/241 [00:03<00:04, 32.74it/s, now=None]
# t:  43% 103/241 [00:03<00:04, 34.37it/s, now=None]
# t:  44% 107/241 [00:03<00:03, 35.15it/s, now=None]
# t:  46% 111/241 [00:03<00:04, 31.86it/s, now=None]
# t:  48% 115/241 [00:03<00:03, 33.05it/s, now=None]
# t:  49% 119/241 [00:03<00:03, 32.73it/s, now=None]
# t:  51% 123/241 [00:03<00:03, 32.49it/s, now=None]
# t:  53% 127/241 [00:03<00:03, 31.01it/s, now=None]
# t:  55% 132/241 [00:04<00:03, 33.76it/s, now=None]
# t:  56% 136/241 [00:04<00:03, 34.07it/s, now=None]
# t:  58% 140/241 [00:04<00:03, 32.22it/s, now=None]
# t:  60% 144/241 [00:04<00:02, 33.15it/s, now=None]
# t:  61% 148/241 [00:04<00:02, 33.78it/s, now=None]
# t:  63% 152/241 [00:04<00:03, 29.15it/s, now=None]
# t:  65% 156/241 [00:04<00:02, 30.02it/s, now=None]
# t:  66% 160/241 [00:04<00:02, 32.01it/s, now=None]
# t:  68% 164/241 [00:05<00:02, 32.84it/s, now=None]
# t:  70% 168/241 [00:05<00:02, 32.77it/s, now=None]
# t:  71% 172/241 [00:05<00:02, 32.65it/s, now=None]
# t:  73% 176/241 [00:05<00:01, 33.62it/s, now=None]
# t:  75% 180/241 [00:05<00:01, 33.28it/s, now=None]
# t:  76% 184/241 [00:05<00:01, 33.13it/s, now=None]
# t:  78% 188/241 [00:05<00:01, 33.11it/s, now=None]
# t:  80% 192/241 [00:05<00:01, 34.02it/s, now=None]
# t:  81% 196/241 [00:06<00:01, 33.87it/s, now=None]
# t:  83% 200/241 [00:06<00:01, 33.75it/s, now=None]
# t:  85% 204/241 [00:06<00:01, 29.51it/s, now=None]
# t:  86% 208/241 [00:06<00:01, 31.10it/s, now=None]
# t:  88% 212/241 [00:06<00:00, 31.98it/s, now=None]
# t:  90% 216/241 [00:06<00:00, 33.46it/s, now=None]
# t:  91% 220/241 [00:06<00:00, 32.18it/s, now=None]
# t:  93% 224/241 [00:06<00:00, 31.09it/s, now=None]
# t:  95% 228/241 [00:07<00:00, 32.05it/s, now=None]
# t:  96% 232/241 [00:07<00:00, 32.87it/s, now=None]
# t:  98% 236/241 [00:07<00:00, 33.16it/s, now=None]
# t: 100% 240/241 [00:07<00:00, 33.70it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/image0_swing.mp4
#  50% 1/2 [13:42<13:42, 822.69s/it]Current Source ==>  final
# Running depth extraction at 1648581953.0347643
# BoostingMonocularDepth/inputs/*.png
# BoostingMonocularDepth/outputs/*.png
# device: cuda
# Namespace(Final=True, R0=False, R20=False, colorize_results=False, data_dir='inputs/', depthNet=0, max_res=inf, net_receptive_field_size=None, output_dir='outputs', output_resolution=1, pix2pixsize=1024, savepatchs=0, savewholeest=0)
# ----------------- Options ---------------
#                     Final: True                          	[default: False]
#                        R0: False
#                       R20: False
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./pix2pix/checkpoints
#          colorize_results: False
#                 crop_size: 672
#                  data_dir: inputs/                       	[default: None]
#                  dataroot: None
#              dataset_mode: depthmerge
#                  depthNet: 0                             	[default: None]
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#             generatevideo: None
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 2
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 672
#          max_dataset_size: 10000
#                   max_res: inf
#                     model: pix2pix4depth
#                n_layers_D: 3
#                      name: void
#                       ndf: 64
#                      netD: basic
#                      netG: unet_1024
#  net_receptive_field_size: None
#                       ngf: 64
#                no_dropout: False
#                   no_flip: False
#                      norm: none
#                  num_test: 50
#               num_threads: 4
#                output_dir: outputs                       	[default: None]
#                 output_nc: 1
#         output_resolution: None
#                     phase: test
#               pix2pixsize: None
#                preprocess: resize_and_crop
#                 savecrops: None
#              savewholeest: None
#            serial_batches: False
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
# initialize network with normal
# loading the model from ./pix2pix/checkpoints/mergemodel/latest_net_G.pth
# Loading weights:  midas/model.pt
# Using cache found in /root/.cache/torch/hub/facebookresearch_WSL-Images_main
# start processing
# libpng warning: iCCP: known incorrect sRGB profile
# processing image 0 : final
# 	 wholeImage being processed in : 1728
#  	 	 DEBUG| GPU THRESHOLD REACHED 1728 ---> 1568
# Adjust factor is: 1.8404004711425208
# Selecting patchs ...
# Target resolution:  (6360, 5253, 3)
# Dynamicly change merged-in resolution; scale: 0.18584905660377357
# 	 Resulted depthmap res will be : (1182, 976)
# patchs to process: 168
# 	 processing patch 0 | [ 24  24 951 951]
# 	 processing patch 1 | [ 24  77 951 951]
# 	 processing patch 2 | [ 24 131 951 951]
# 	 processing patch 3 | [ 24 185 951 951]
# 	 processing patch 4 | [ 35 249 930 930]
# 	 processing patch 5 | [  3   3 886 886]
# 	 processing patch 6 | [  3  56 886 886]
# 	 processing patch 7 | [  3 110 886 886]
# 	 processing patch 8 | [  3 163 886 886]
# 	 processing patch 9 | [  3 217 886 886]
# 	 processing patch 10 | [  3 270 886 886]
# 	 processing patch 11 | [ 56   3 886 886]
# 	 processing patch 12 | [131  24 843 843]
# 	 processing patch 13 | [131  78 843 843]
# 	 processing patch 14 | [131 131 843 843]
# 	 processing patch 15 | [131 185 843 843]
# 	 processing patch 16 | [131 238 843 843]
# 	 processing patch 17 | [ 35 356 822 822]
# 	 processing patch 18 | [ 89 356 822 822]
# 	 processing patch 19 | [142 356 822 822]
# 	 processing patch 20 | [  3  57 779 779]
# 	 processing patch 21 | [  3 110 779 779]
# 	 processing patch 22 | [  3 164 779 779]
# 	 processing patch 23 | [  3 217 779 779]
# 	 processing patch 24 | [  3 271 779 779]
# 	 processing patch 25 | [  3 324 779 779]
# 	 processing patch 26 | [  3 378 779 779]
# 	 processing patch 27 | [ 57   3 779 779]
# 	 processing patch 28 | [110   3 779 779]
# 	 processing patch 29 | [164   3 779 779]
# 	 processing patch 30 | [  9   9 768 768]
# 	 processing patch 31 | [239  78 736 736]
# 	 processing patch 32 | [239 132 736 736]
# 	 processing patch 33 | [239 185 736 736]
# 	 processing patch 34 | [239 239 736 736]
# 	 processing patch 35 | [239 399 736 736]
# 	 processing patch 36 | [ 35 464 714 714]
# 	 processing patch 37 | [ 89 464 714 714]
# 	 processing patch 38 | [143 464 714 714]
# 	 processing patch 39 | [196 464 714 714]
# 	 processing patch 40 | [250 464 714 714]
# 	 processing patch 41 | [  4  57 671 671]
# 	 processing patch 42 | [  4 111 671 671]
# 	 processing patch 43 | [  4 164 671 671]
# 	 processing patch 44 | [  4 218 671 671]
# 	 processing patch 45 | [  4 271 671 671]
# 	 processing patch 46 | [  4 325 671 671]
# 	 processing patch 47 | [  4 378 671 671]
# 	 processing patch 48 | [  4 432 671 671]
# 	 processing patch 49 | [  4 485 671 671]
# 	 processing patch 50 | [ 57   4 671 671]
# 	 processing patch 51 | [111   4 671 671]
# 	 processing patch 52 | [164   4 671 671]
# 	 processing patch 53 | [277  62 660 660]
# 	 processing patch 54 | [346 400 628 628]
# 	 processing patch 55 | [346 453 628 628]
# 	 processing patch 56 | [346 507 628 628]
# 	 processing patch 57 | [ 36 571 606 606]
# 	 processing patch 58 | [ 89 571 606 606]
# 	 processing patch 59 | [143 571 606 606]
# 	 processing patch 60 | [196 571 606 606]
# 	 processing patch 61 | [250 571 606 606]
# 	 processing patch 62 | [303 571 606 606]
# 	 processing patch 63 | [357 571 606 606]
# 	 processing patch 64 | [266  52 574 574]
# 	 processing patch 65 | [  4  57 563 563]
# 	 processing patch 66 | [  4 111 563 563]
# 	 processing patch 67 | [  4 164 563 563]
# 	 processing patch 68 | [  4 218 563 563]
# 	 processing patch 69 | [  4 272 563 563]
# 	 processing patch 70 | [  4 432 563 563]
# 	 processing patch 71 | [  4 486 563 563]
# 	 processing patch 72 | [  4 539 563 563]
# 	 processing patch 73 | [  4 593 563 563]
# 	 processing patch 74 | [164   4 563 563]
# 	 processing patch 75 | [218   4 563 563]
# 	 processing patch 76 | [293  25 520 520]
# 	 processing patch 77 | [347  79 520 520]
# 	 processing patch 78 | [454 454 520 520]
# 	 processing patch 79 | [454 507 520 520]
# 	 processing patch 80 | [454 561 520 520]
# 	 processing patch 81 | [454 614 520 520]
# 	 processing patch 82 | [ 36 679 498 498]
# 	 processing patch 83 | [ 90 679 498 498]
# 	 processing patch 84 | [143 679 498 498]
# 	 processing patch 85 | [197 679 498 498]
# 	 processing patch 86 | [250 679 498 498]
# 	 processing patch 87 | [304 679 498 498]
# 	 processing patch 88 | [357 679 498 498]
# 	 processing patch 89 | [411 679 498 498]
# 	 processing patch 90 | [464 679 498 498]
# 	 processing patch 91 | [  4  58 455 455]
# 	 processing patch 92 | [  4 111 455 455]
# 	 processing patch 93 | [  4 165 455 455]
# 	 processing patch 94 | [  4 218 455 455]
# 	 processing patch 95 | [  4 272 455 455]
# 	 processing patch 96 | [  4 540 455 455]
# 	 processing patch 97 | [  4 593 455 455]
# 	 processing patch 98 | [  4 647 455 455]
# 	 processing patch 99 | [  4 700 455 455]
# 	 processing patch 100 | [561 454 412 412]
# 	 processing patch 101 | [561 508 412 412]
# 	 processing patch 102 | [561 561 412 412]
# 	 processing patch 103 | [561 615 412 412]
# 	 processing patch 104 | [561 668 412 412]
# 	 processing patch 105 | [561 722 412 412]
# 	 processing patch 106 | [ 31 781 401 401]
# 	 processing patch 107 | [ 85 781 401 401]
# 	 processing patch 108 | [138 781 401 401]
# 	 processing patch 109 | [192 781 401 401]
# 	 processing patch 110 | [245 781 401 401]
# 	 processing patch 111 | [299 781 401 401]
# 	 processing patch 112 | [352 781 401 401]
# 	 processing patch 113 | [406 781 401 401]
# 	 processing patch 114 | [459 781 401 401]
# 	 processing patch 115 | [  5  58 348 348]
# 	 processing patch 116 | [  5 112 348 348]
# 	 processing patch 117 | [  5 165 348 348]
# 	 processing patch 118 | [  5 219 348 348]
# 	 processing patch 119 | [  5 272 348 348]
# 	 processing patch 120 | [  5 754 348 348]
# 	 processing patch 121 | [  5 808 348 348]
# 	 processing patch 122 | [ 80 561 304 304]
# 	 processing patch 123 | [668 508 304 304]
# 	 processing patch 124 | [668 561 304 304]
# 	 processing patch 125 | [668 615 304 304]
# 	 processing patch 126 | [668 668 304 304]
# 	 processing patch 127 | [668 722 304 304]
# 	 processing patch 128 | [668 776 304 304]
# 	 processing patch 129 | [ 32 888 294 294]
# 	 processing patch 130 | [ 85 888 294 294]
# 	 processing patch 131 | [139 888 294 294]
# 	 processing patch 132 | [192 888 294 294]
# 	 processing patch 133 | [246 888 294 294]
# 	 processing patch 134 | [299 888 294 294]
# 	 processing patch 135 | [406 888 294 294]
# 	 processing patch 136 | [460 888 294 294]
# 	 processing patch 137 | [513 888 294 294]
# 	 processing patch 138 | [ 91  37 283 283]
# 	 processing patch 139 | [ 42  42 272 272]
# 	 processing patch 140 | [  5 166 240 240]
# 	 processing patch 141 | [  5 219 240 240]
# 	 processing patch 142 | [  5 273 240 240]
# 	 processing patch 143 | [  5 861 240 240]
# 	 processing patch 144 | [  5 915 240 240]
# 	 processing patch 145 | [ 59 701 240 240]
# 	 processing patch 146 | [ 64 653 229 229]
# 	 processing patch 147 | [123  16 218 218]
# 	 processing patch 148 | [ 75  21 207 207]
# 	 processing patch 149 | [776 562 197 197]
# 	 processing patch 150 | [776 615 197 197]
# 	 processing patch 151 | [776 669 197 197]
# 	 processing patch 152 | [776 722 197 197]
# 	 processing patch 153 | [776 776 197 197]
# 	 processing patch 154 | [ 85 995 186 186]
# 	 processing patch 155 | [139 995 186 186]
# 	 processing patch 156 | [193  32 186 186]
# 	 processing patch 157 | [193 995 186 186]
# 	 processing patch 158 | [246 995 186 186]
# 	 processing patch 159 | [300 995 186 186]
# 	 processing patch 160 | [353 995 186 186]
# 	 processing patch 161 | [460 995 186 186]
# 	 processing patch 162 | [514 995 186 186]
# 	 processing patch 163 | [567 995 186 186]
# 	 processing patch 164 | [ 96 632 164 164]
# 	 processing patch 165 | [107   0 143 143]
# 	 processing patch 166 | [161   0 143 143]
# 	 processing patch 167 | [214   0 143 143]
# finished
#  50% 1/2 [15:15<15:15, 915.91s/it]
# Traceback (most recent call last):
#   File "main.py", line 76, in <module>
#     vis_photos, vis_depths = sparse_bilateral_filtering(depth.copy(), image.copy(), config, num_iter=config['sparse_iter'], spdb=False)
#   File "/content/drive/MyDrive/pixray/3d-photo-inpainting/bilateral_filtering.py", line 31, in sparse_bilateral_filtering
#     vis_image[u_over > 0] = np.array([0, 0, 0])
# ValueError: shape mismatch: value array of shape (3,) could not be broadcast to indexing result of shape (2066,4)

# %%
import yaml

with open('/content/drive/MyDrive/pixray/3d-photo-inpainting/argument.yml') as file:
    documents = yaml.load(file)

    for item, doc in documents.items():
        print(item, ":", doc)
# Out:
# depth_edge_model_ckpt : checkpoints/edge-model.pth
# depth_feat_model_ckpt : checkpoints/depth-model.pth
# rgb_feat_model_ckpt : checkpoints/color-model.pth
# MiDaS_model_ckpt : MiDaS/model.pt
# use_boostmonodepth : True
# fps : 40
# num_frames : 240
# x_shift_range : [0.0, 0.0, -0.015, -0.015]
# y_shift_range : [0.0, 0.0, -0.015, -0.0]
# z_shift_range : [-0.05, -0.05, -0.05, -0.05]
# traj_types : ['double-straight-line', 'double-straight-line', 'circle', 'circle']
# video_postfix : ['dolly-zoom-in', 'zoom-in', 'circle', 'swing']
# specific :
# longer_side_len : 2000
# src_folder : image
# depth_folder : depth
# mesh_folder : mesh
# video_folder : video
# load_ply : False
# save_ply : True
# inference_video : True
# gpu_ids : 0
# offscreen_rendering : False
# img_format : .png
# depth_format : .npy
# require_midas : True
# depth_threshold : 0.04
# ext_edge_threshold : 0.002
# sparse_iter : 5
# filter_size : [7, 7, 5, 5, 5]
# sigma_s : 4.0
# sigma_r : 0.5
# redundant_number : 12
# background_thickness : 70
# context_thickness : 140
# background_thickness_2 : 70
# context_thickness_2 : 70
# discount_factor : 1.0
# log_depth : True
# largest_size : 512
# depth_edge_dilate : 10
# depth_edge_dilate_2 : 5
# extrapolate_border : True
# extrapolation_thickness : 60
# repeat_inpaint_edge : True
# crop_border : [0.03, 0.03, 0.05, 0.03]
# anti_flickering : True

# %%
import yaml

dict_file = [{'sports' : ['soccer', 'football', 'basketball', 'cricket', 'hockey', 'table tennis']},
{'countries' : ['Pakistan', 'USA', 'India', 'China', 'Germany', 'France', 'Spain']}]

with open(r'E:\data\store_file.yaml', 'w') as file:

    documents = yaml.dump(dict_file, file)8

# %%
yaml_dict = yaml.safe_load('')
print(yaml_dict)
# Out:
# /content/drive/MyDrive/pixray/3d-photo-inpainting/argument.yml

# %%
import yaml
from pathlib import Path
conf = yaml.safe_load(Path('/content/drive/MyDrive/pixray/3d-photo-inpainting/argument.yml').read_text())

# %%
def change_yaml(largest_size, total_frames, fps, longest_side, path):

  #largest_size = 512
  #total_frames = 240
  #fps = 40
  #longest_side = 2000
  yaml_dict = {'MiDaS_model_ckpt': 'MiDaS/model.pt',
  'anti_flickering': True,
  'background_thickness': 70,
  'background_thickness_2': 70,
  'context_thickness': 140,
  'context_thickness_2': 70,
  'crop_border': [0.03, 0.03, 0.05, 0.03],
  'depth_edge_dilate': 10,
  'depth_edge_dilate_2': 5,
  'depth_edge_model_ckpt': 'checkpoints/edge-model.pth',
  'depth_feat_model_ckpt': 'checkpoints/depth-model.pth',
  'depth_folder': 'depth',
  'depth_format': '.npy',
  'depth_threshold': 0.04,
  'discount_factor': 1.0,
  'ext_edge_threshold': 0.002,
  'extrapolate_border': True,
  'extrapolation_thickness': 60,
  'filter_size': [7, 7, 5, 5, 5],
  'fps': {fps},
  'gpu_ids': 0,
  'img_format': '.png',
  'inference_video': True,
  'largest_size': {int(largest_size)},
  'load_ply': False,
  'log_depth': True,
  'longer_side_len': {int(longest_side)},
  'mesh_folder': 'mesh',
  'num_frames': {int(total_frames)},
  'offscreen_rendering': False,
  'redundant_number': 12,
  'repeat_inpaint_edge': True,
  'require_midas': True,
  'rgb_feat_model_ckpt': 'checkpoints/color-model.pth',
  'save_ply': True,
  'sigma_r': 0.5,
  'sigma_s': 4.0,
  'sparse_iter': 5,
  'specific': '',
  'src_folder': 'image',
  'traj_types': ['double-straight-line',
    'double-straight-line',
    'circle',
    'circle'],
  'use_boostmonodepth': True,
  'video_folder': 'video',
  'video_postfix': ['dolly-zoom-in', 'zoom-in', 'circle', 'swing'],
  'x_shift_range': [0.0, 0.0, -0.015, -0.015],
  'y_shift_range': [0.0, 0.0, -0.015, -0.0],
  'z_shift_range': [-0.05, -0.05, -0.05, -0.05]}

  with open(path, 'w') as file:
    yaml.dump(yaml_dict, file)

# %%
change_yaml(513, 250, 60, 2001, '/content/argument.yml')
